# %%
import pandas as pd
import numpy as np
import talib as ta
from pandas_datareader import data
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')
import datetime as dt

# %%
start = dt.datetime(2017, 7, 1)
end = dt.datetime(2020, 7, 1)

df = data.get_data_yahoo('^N225', start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head(10)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2017-07-03  20056.320312  20096.140625  20030.609375  20055.800781
# 2017-07-04  20192.269531  20197.160156  19971.529297  20032.349609
# 2017-07-05  20015.070312  20087.009766  19888.900391  20081.630859
# 2017-07-06  20061.679688  20078.880859  19947.630859  19994.060547
# 2017-07-07  19856.650391  19979.929688  19856.650391  19929.089844
# 2017-07-10  20070.439453  20127.759766  20023.029297  20080.980469
# 2017-07-11  20073.859375  20200.880859  20070.669922  20195.480469
# 2017-07-12  20137.220703  20153.039062  20061.160156  20098.380859
# 2017-07-13  20177.279297  20183.800781  20062.269531  20099.810547
# 2017-07-14  20157.919922  20163.669922  20101.710938  20118.859375
#
#                Adj Close     Volume
# Date
# 2017-07-03  20055.800781   83400000
# 2017-07-04  20032.349609  100300000
# 2017-07-05  20081.630859   94600000
# 2017-07-06  19994.060547   92700000
# 2017-07-07  19929.089844   91900000
# 2017-07-10  20080.980469   85700000
# 2017-07-11  20195.480469   77300000
# 2017-07-12  20098.380859   81400000
# 2017-07-13  20099.810547   90500000
# 2017-07-14  20118.859375   83100000

# %%
date = df.index # X軸に日付を指定
close = df['Close'] # Y軸に株価を指定

# %%
span01 = 5
span02 = 25
span03 = 50

df['SMA01'] = close.rolling(window=span01).mean()
df['SMA02'] = close.rolling(window=span02).mean()
df['SMA03'] = close.rolling(window=span03).mean()

# %%
plt.figure(figsize=(20, 10)) # グラフのサイズを指定

plt.subplot(2, 1, 1)  # 2行1列のグラフの1番目のグラフを表示
plt.plot(date, close, label='Close', color='#99b898')  # X軸に日付、Y軸に株価、Closeを表示
plt.plot(date, df['SMA01'], label='SMA01', color='#e84a5f')  # X軸に日付、Y軸に移動平均線、SMA01を表示
plt.plot(date, df['SMA02'], label='SMA02', color='#ff847c')  # X軸に日付、Y軸に移動平均線、SMA02を表示
plt.plot(date, df['SMA03'], label='SMA03', color='#feceab')  # X軸に日付、Y軸に移動平均線、SMA03を表示
plt.legend()
    
plt.subplot(2, 1, 2)  # 2行1列のグラフの2番目のグラフを表示
plt.bar(date, df['Volume'], label='Volume', color='gray') # X軸に日付、Y軸に出来高、Volumeを表示
plt.legend()  # 凡例を表示

# %%
df['macd'], df['macdsignal'], df['macdhist'] = ta.MACD(close, fastperiod=12, slowperiod=26, signalperiod=9)

# %%
df.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2017-07-03  20056.320312  20096.140625  20030.609375  20055.800781
# 2017-07-04  20192.269531  20197.160156  19971.529297  20032.349609
# 2017-07-05  20015.070312  20087.009766  19888.900391  20081.630859
# 2017-07-06  20061.679688  20078.880859  19947.630859  19994.060547
# 2017-07-07  19856.650391  19979.929688  19856.650391  19929.089844
#
#                Adj Close     Volume         SMA01  SMA02  SMA03  macd  \
# Date
# 2017-07-03  20055.800781   83400000           NaN    NaN    NaN   NaN
# 2017-07-04  20032.349609  100300000           NaN    NaN    NaN   NaN
# 2017-07-05  20081.630859   94600000           NaN    NaN    NaN   NaN
# 2017-07-06  19994.060547   92700000           NaN    NaN    NaN   NaN
# 2017-07-07  19929.089844   91900000  20018.586328    NaN    NaN   NaN
#
#             macdsignal  macdhist
# Date
# 2017-07-03         NaN       NaN
# 2017-07-04         NaN       NaN
# 2017-07-05         NaN       NaN
# 2017-07-06         NaN       NaN
# 2017-07-07         NaN       NaN

# %%
df.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-06-24  22541.009766  22663.289062  22479.859375  22534.320312
# 2020-06-25  22287.869141  22423.410156  22165.140625  22259.789062
# 2020-06-26  22424.369141  22589.140625  22408.269531  22512.080078
# 2020-06-29  22255.050781  22281.380859  21969.589844  21995.039062
# 2020-06-30  22335.099609  22448.300781  22273.380859  22288.140625
#
#                Adj Close    Volume         SMA01         SMA02         SMA03  \
# Date
# 2020-06-24  22534.320312  67000000  22470.978125  22152.969297  20977.637188
# 2020-06-25  22259.789062  80800000  22451.843750  22221.268437  21032.862969
# 2020-06-26  22512.080078  66600000  22458.501953  22306.225234  21102.236562
# 2020-06-29  21995.039062  73700000  22370.055859  22356.360781  21149.361133
# 2020-06-30  22288.140625  74200000  22317.873828  22397.039609  21204.122148
#
#                   macd  macdsignal    macdhist
# Date
# 2020-06-24  419.265686  518.700440  -99.434755
# 2020-06-25  375.920749  490.144502 -114.223754
# 2020-06-26  357.802822  463.676166 -105.873344
# 2020-06-29  298.284903  430.597913 -132.313010
# 2020-06-30  271.636118  398.805554 -127.169436

# %%
plt.figure(figsize=(20, 10)) # グラフのサイズを指定
plt.subplot(2,1,1)

plt.plot(date, close, label='Close', color='#99b898') # close_dataを使用してグラフを描画
plt.legend()

plt.subplot(2,1,2)
plt.fill_between(date, df['macdhist'], color='gray', alpha=0.5, label='MACD_hist')
plt.hlines(0, start, end, 'gray', linestyles='dashed')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-179b52616698> in <module>
#       7 plt.subplot(2,1,2)
#       8 plt.fill_between(date, df['macdhist'], color='gray', alpha=0.5, label='MACD_hist')
# ----> 9 plt.hlines(0, start, end, 'gray', linestyles='dashed')
#      10 plt.legend()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in hlines(y, xmin, xmax, colors, linestyles, label, data, **kwargs)
#    2681         y, xmin, xmax, colors=colors, linestyles=linestyles,
#    2682         label=label, **({"data": data} if data is not None else {}),
# -> 2683         **kwargs)
#    2684
#    2685
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in hlines(self, y, xmin, xmax, colors, linestyles, label, **kwargs)
#    1042         self._process_unit_info([xmin, xmax], y, kwargs=kwargs)
#    1043         y = self.convert_yunits(y)
# -> 1044         xmin = self.convert_xunits(xmin)
#    1045         xmax = self.convert_xunits(xmax)
#    1046
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     184         if ax is None or ax.xaxis is None:
#     185             return x
# --> 186         return ax.xaxis.convert_units(x)
#     187
#     188     def convert_yunits(self, y):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1528             return x
#    1529
# -> 1530         ret = self.converter.convert(x, self.units, self)
#    1531         return ret
#    1532
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in convert(value, unit, axis)
#    1816         The *unit* and *axis* arguments are not used.
#    1817         """
# -> 1818         return date2num(value)
#    1819
#    1820     @staticmethod
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in date2num(d)
#     425         if not d.size:
#     426             return d
# --> 427         return _to_ordinalf_np_vectorized(d)
#     428
#     429
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2161             vargs.extend([kwargs[_n] for _n in names])
#    2162
# -> 2163         return self._vectorize_call(func=func, args=vargs)
#    2164
#    2165     def _get_ufunc_and_otypes(self, func, args):
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2239             res = func()
#    2240         else:
# -> 2241             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2242
#    2243             # Convert args to object arrays first
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2199
#    2200             inputs = [arg.flat[0] for arg in args]
# -> 2201             outputs = func(*inputs)
#    2202
#    2203             # Performance note: profiling indicates that -- for simple
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in _to_ordinalf(dt)
#     226         tzi = UTC
#     227
# --> 228     base = float(dt.toordinal())
#     229
#     230     # If it's sufficiently datetime-like, it will have a `date()` method
#
# AttributeError: 'numpy.str_' object has no attribute 'toordinal'

# %%
df['RSI'] = ta.RSI(close, timeperiod=span02)

# %%
df.tail()
# Out:
#                Open     High      Low    Close    Volume     SMA01      SMA02  \
# Date
# 2019-07-05  1335.65  1341.67  1332.55  1336.04  17228675  1336.818  1355.0548
# 2019-07-04  1331.00  1335.27  1327.12  1331.97  12432305  1336.934  1355.2952
# 2019-07-03  1323.44  1330.61  1318.20  1322.85  19411330  1333.558  1355.3804
# 2019-07-02  1330.22  1337.01  1324.60  1335.07  21683695  1332.356  1356.1020
# 2019-07-01  1311.99  1333.13  1304.62  1333.13  30141025  1331.812  1357.2964
#
#                 SMA03      macd  macdsignal  macdhist        RSI
# Date
# 2019-07-05  1356.3934 -5.904359   -2.116992 -3.787367  43.719010
# 2019-07-04  1354.1554 -6.766413   -3.046876 -3.719537  43.002894
# 2019-07-03  1351.9250 -8.092223   -4.055946 -4.036278  41.419295
# 2019-07-02  1350.1602 -8.063929   -4.857542 -3.206387  44.283076
# 2019-07-01  1348.2944 -8.104623   -5.506958 -2.597664  43.927947

# %%
plt.figure(figsize=(20, 10)) # グラフのサイズを指定
plt.subplot(2,1,1)

plt.plot(date, close, label='Close', color='#99b898') # close_dataを使用してグラフを描画
plt.plot(date, df['SMA01'], label='SMA01', color='#e84a5f')  # X軸に日付、Y軸に移動平均線、SMA01を表示
plt.plot(date, df['SMA02'], label='SMA02', color='#ff847c')  # X軸に日付、Y軸に移動平均線、SMA02を表示
plt.plot(date, df['SMA03'], label='SMA03', color='#feceab')  # X軸に日付、Y軸に移動平均線、SMA03を表示
plt.legend()

plt.subplot(2,1,2)
plt.plot(date, df['RSI'], label='RSI', color='gray')
plt.ylim(0, 100)
plt.hlines([30,50,70], start, end, 'grey', linestyles='dashed')
plt.legend()

# %%
df['upper'], df['middle'], df['lower'] = ta.BBANDS(close, timeperiod=span02, nbdevup=2,nbdevdn=2, matype=0)

# %%
df.tail()
# Out:
#                Open     High      Low    Close    Volume     SMA01      SMA02  \
# Date
# 2019-07-05  1335.65  1341.67  1332.55  1336.04  17228675  1336.818  1355.0548
# 2019-07-04  1331.00  1335.27  1327.12  1331.97  12432305  1336.934  1355.2952
# 2019-07-03  1323.44  1330.61  1318.20  1322.85  19411330  1333.558  1355.3804
# 2019-07-02  1330.22  1337.01  1324.60  1335.07  21683695  1332.356  1356.1020
# 2019-07-01  1311.99  1333.13  1304.62  1333.13  30141025  1331.812  1357.2964
#
#                 SMA03      macd  macdsignal  macdhist        RSI        upper  \
# Date
# 2019-07-05  1356.3934 -5.904359   -2.116992 -3.787367  43.719010  1408.461155
# 2019-07-04  1354.1554 -6.766413   -3.046876 -3.719537  43.002894  1408.227531
# 2019-07-03  1351.9250 -8.092223   -4.055946 -4.036278  41.419295  1408.096262
# 2019-07-02  1350.1602 -8.063929   -4.857542 -3.206387  44.283076  1407.166281
# 2019-07-01  1348.2944 -8.104623   -5.506958 -2.597664  43.927947  1404.621797
#
#                middle        lower
# Date
# 2019-07-05  1355.0548  1301.648445
# 2019-07-04  1355.2952  1302.362869
# 2019-07-03  1355.3804  1302.664538
# 2019-07-02  1356.1020  1305.037719
# 2019-07-01  1357.2964  1309.971003

# %%
plt.figure(figsize=(20, 10)) # グラフのサイズを指定

plt.plot(date, close, label='Close', color='#99b898') # close_dataを使用してグラフを描画
plt.fill_between(date, df['upper'], df['lower'], color='gray', alpha=0.3)
plt.legend()

# %%
plt.figure(figsize=(20, 10)) # グラフのサイズを指定

# 移動平均
plt.subplot(5, 1, 1)  # 2行1列のグラフの1番目のグラフを表示
plt.plot(date, close, label='Close', color='#99b898')  # X軸に日付、Y軸に株価、Closeを表示
plt.plot(date, df['SMA01'], label='SMA01', color='#e84a5f')  # X軸に日付、Y軸に移動平均線、SMA01を表示
plt.plot(date, df['SMA02'], label='SMA02', color='#ff847c')  # X軸に日付、Y軸に移動平均線、SMA02を表示
plt.plot(date, df['SMA03'], label='SMA03', color='#feceab')  # X軸に日付、Y軸に移動平均線、SMA03を表示
plt.legend()

# 出来高
plt.subplot(5, 1, 2)  # 2行1列のグラフの2番目のグラフを表示
plt.bar(date, df['Volume'], label='Volume', color='gray') # X軸に日付、Y軸に出来高、Volumeを表示
plt.legend()  # 凡例を表示

# MACD
plt.subplot(5, 1, 3) 
plt.fill_between(date, df['macdhist'], color='grey', alpha=0.5, label='MACD_hist')
plt.hlines(0, start, end, 'gray', linestyles='dashed')
plt.legend()

# RSI
plt.subplot(5, 1, 4) 
plt.plot(date, df['RSI'], label='RSI', color='gray')
plt.ylim(0, 100)
plt.hlines([30,50,70], start, end, 'grey', linestyles='dashed')
plt.legend()

# ボリンジャーバンド
plt.subplot(5, 1, 5) 
plt.plot(date, close, label='Close', color='#99b898') # close_dataを使用してグラフを描画
plt.fill_between(date, df['upper'], df['lower'], color='gray', alpha=0.3)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-51b63b5272e1> in <module>
#       3 # 移動平均
#       4 plt.subplot(5, 1, 1)  # 2行1列のグラフの1番目のグラフを表示
# ----> 5 plt.plot(date, close, label='Close', color='#99b898')  # X軸に日付、Y軸に株価、Closeを表示
#       6 plt.plot(date, df['SMA01'], label='SMA01', color='#e84a5f')  # X軸に日付、Y軸に移動平均線、SMA01を表示
#       7 plt.plot(date, df['SMA02'], label='SMA02', color='#ff847c')  # X軸に日付、Y軸に移動平均線、SMA02を表示
#
# NameError: name 'date' is not defined
